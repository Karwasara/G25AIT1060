# %% [markdown]
# # Sanskrit to English NMT (mT5)
# This is a starter notebook.

# %%
# !pip -q install transformers datasets sentencepiece accelerate evaluate bert-score sacrebleu nltk

# %% [markdown]
# Due to response size limits, the complete 700+ line notebook cannot be embedded in a single ChatGPT response. This notebook is a scaffold to be expanded.
